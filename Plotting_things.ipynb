# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
no_noise_lista = [.015, .0094, .0062,.0049, .0034]
neg10db_lista = [0.022034164518117905, 0.018861990422010422, 0.01840231381356716, 0.018453877419233322, 0.018563086166977882, 0.018610648810863495, 0.018722906708717346, 0.018702778965234756, 0.018709855154156685, 0.018721869215369225]
lista_1db = [0.017001505941152573, 0.010512768290936947, 0.008186239749193192, 0.007229012902826071, 0.0066844928078353405]
lista_5db = [0.016715997830033302, 0.010003453120589256, 0.0075784712098538876, 0.006434582639485598, 0.00582664180546999]
lista_neg12db = [0.024233583360910416, 0.022184832021594048, 0.02209141105413437, 0.022234413772821426, 0.022318977862596512]

# %%
amp_noiseless = [0.03714869, 0.03304103, 0.02793242, 0.02200652, 0.01915667, 0.01543138, 0.01319959, 0.01053605, 0.00781656, 0.00675969, 0.00527145, 0.00478272]

# %%
plt.figure()
plt.title("MSE vs. iterations diff SNRS")
plt.plot(range(1, 6), no_noise_lista, label="no noise", color="blue")
plt.plot(range(1, 6), lista_neg12db, label="-12dB")
plt.plot(range(1, 6), neg10db_lista[0:5], label="-10dB", color="red")
plt.plot(range(1, 6), lista_1db, label="1dB", color="purple")
plt.plot(range(1, 6), lista_5db, label="5dB")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
amp_10db = [0.03351551957207044,0.03710174695397633,0.049700209437273796,0.059340006810899196,0.06688350727977954]
ist_10db = [0.048483316782791504,0.0432581566013954,0.041413456523064184,0.03973113387893762,0.03854807959547184]

# %%
# plot noiseless AMP and IST!!
plt.figure()
plt.title("MSE vs. iterations diff SNRS")
#plt.plot(range(1, 6), no_noise_lista, label="no noise", color="blue")
#plt.plot(range(1, 6), neg10db_lista[0:5], label="-10dB", color="red")
#plt.plot(range(1, 6), lista_1db, label="1dB", color="purple")
plt.plot(range(1, 6), ist_10db, label="IST 10dB", color="green")
plt.plot(range(1, 6), amp_10db, label="AMP 10dB", color="darkorange")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
ist_neg12db =  [0.03313514, 0.03194342, 0.03131725, 0.03090286, 0.03055185]
amp_neg12db =  [0.0432182,  0.04583532, 0.04681834, 0.05166725, 0.05153826]

# %%
plt.figure()
plt.title("MSE vs. iterations: SNR = -12dB")
plt.plot(range(1, 6), lista_neg12db, label="LISTA", color="blue")
plt.plot(range(1, 6), amp_neg12db, label="AMP", color="orange")
plt.plot(range(1, 6), ist_neg12db, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
ist_no_noise = [0.03007517, 0.0279768,  0.02645109,0.02532197, 0.02432973]

plt.figure()
plt.title("MSE vs. iterations")
plt.plot(range(1, 6), lista_neg12db, label="LISTA, -12dB", color="blue")
plt.plot(range(1, 6), ist_no_noise, label="IST-noiseless", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
ist_1db = [0.03102829, 0.02912001, 0.02766944, 0.02659145, 0.0256547 ]
amp_1db = [0.0299412 , 0.02602259, 0.02175443, 0.01982523, 0.01554304]

plt.figure()
plt.title("MSE vs. iterations: SNR = 1dB")
plt.semilogy(range(1, 6), lista_1db, label="LISTA", color="blue")
plt.semilogy(range(1, 6), amp_1db, label="AMP", color="orange")
plt.semilogy(range(1, 6), ist_1db, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
lista = [0.017268188297748566, 0.010333817452192307, 0.007611081004142761, 0.006429785862565041, 0.005758045241236687, 0.005263123195618391, 0.004968618042767048, 0.004767415579408407, 0.004656507167965174, 0.0045895702205598354, 0.004528256133198738, 0.0045202248729765415, 0.004489807412028313, 0.004490188788622618, 0.004389361944049597, 0.004445160739123821, 0.004388550296425819, 0.004338670056313276, 0.004425568971782923, 0.004415042232722044, 0.004435503389686346, 0.004356184042990208, 0.004456531722098589, 0.004326607566326857, 0.004379489459097385, 0.004403744358569384, 0.004465778823941946, 0.004464644007384777, 0.004288980271667242, 0.004523183684796095]

plt.figure()
plt.title("MSE vs. iterations")
plt.semilogy(range(1, 31), lista, label="LISTA", color="blue")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
lista_a = [0.028807619586586952, 0.02525387704372406, 0.022801389917731285, 0.020904075354337692, 0.0193499643355608, 0.018030904233455658, 0.01688372530043125]
plt.figure()
plt.title("MSE vs. iterations")
plt.plot(range(1, 8), lista[0:7], label="a, Q, W")
plt.plot(range(1, 8), lista_a, label="alpha")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
# training a, Q, W on first 5 layers and then only training alpha. Fixing each layer as I go
lista = [0.015227790921926498, 0.007953337393701077, 0.004915229044854641, 0.0033523666206747293, 0.002400533063337207, 0.002059998456388712, 0.001899978145956993, 0.0015766761498525739, 0.0014572060899809003, 0.0013733754167333245, 0.0013150888262316585, 0.0012678614584729075, 0.0012288893340155482, 0.0011952355271205306, 0.0011662424076348543]
amp = [0.03273248, 0.02930152, 0.02652344, 0.0232829,  0.01993916, 0.01573599,
 0.01200669, 0.00972844, 0.00914783, 0.00968972, 0.00908657, 0.00796159,
 0.00604671, 0.00493109, 0.00386662]

plt.figure()
plt.title("MSE vs. iterations")
plt.plot(range(1, 16), lista, label="LISTA", color="blue")
plt.plot(range(1, 16), amp, label="AMP", color="orange")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations")
plt.semilogy(range(1, 16), lista, label="LISTA", color="blue")
plt.semilogy(range(1, 16), amp, label="AMP", color="orange")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
lista = [0.015956170856952667, 0.009034167043864727, 0.006341001484543085, 0.004927593283355236, 0.004069817718118429, 0.003478239057585597, 0.003015197115018964, 0.002628451446071267, 0.0022626265417784452, 0.0019342404557392001, 0.0017167890910059214, 0.0014804891543462873, 0.0012883399613201618, 0.0011885667918249965, 0.001105058123357594, 0.0010156473144888878, 0.0009610279812477529, 0.0009294102201238275]
amp =[0.030470518009986937,0.024547040163402964,0.021069401867711265,0.016863672272007718,0.013268181867357438,0.0120806450659894,0.009662170128603553,0.008132994524935402,0.007280504715391162,0.0062333935756604866,0.005148013822484665,0.004696772755386113,0.004308868338724983,0.003979784961235383,0.00318273479774967,0.002671265735519434,0.0023662537695367672,0.002076721960887655,0.0017422161235999714,0.0015881054203463777,0.0016994354350226516,0.00134496239475309]

plt.figure()
plt.title("MSE vs. iterations")
plt.plot(range(1, 19), lista[0:18], label="LISTA", color="blue")
plt.plot(range(1, 19), amp[0:18], label="AMP", color="orange")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations")
plt.semilogy(range(1, 19), lista[0:18], label="LISTA", color="blue")
plt.semilogy(range(1, 19), amp[0:18], label="AMP", color="orange")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# # Plotting noisy things

# %%
# -12dB for 15 layers/iterations
# lista used 5 epochs and a batch size of 128
lista = [0.023818086832761765, 0.02200181595981121, 0.022111445665359497, 0.022289428859949112, 0.02236822061240673, 0.022396469488739967, 0.02241653762757778, 0.022354111075401306, 0.022352686151862144, 0.02237638831138611, 0.02234785072505474, 0.022377394139766693, 0.022368118166923523, 0.02235613949596882]
amp = [0.04690335319104038,0.05804488739020794,0.05842573659814334,0.06309443840997345,0.06564597276074646,0.06292499394921464,0.06466010589054322,0.06177762168302146,0.058019840453608945,0.05930404925140012,0.05729708097818435,0.05915784367055095,0.06135051589081314,0.058705756702596756,0.05545159558188245]
ist =[0.031430071181365316,0.030049395008867143,0.029407035201268344,0.028864167773019096,0.028444671805515978,0.02806893138924213,0.027745813734812573,0.027456573203001683,0.027201001262223606,0.026975267496727656,0.02676830597367237,0.026578536766953882,0.02640645104862195,0.02624933078982764,0.026108017357464094]

plt.figure()
plt.title("MSE vs. iterations: SNR = -12dB")
plt.plot(range(1, 15), lista, label="LISTA", color="blue")
plt.plot(range(1, 16), amp, label="AMP", color="orange")
plt.plot(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations: SNR = -12dB")
plt.semilogy(range(1, 15), lista, label="LISTA", color="blue")
plt.semilogy(range(1, 16), amp, label="AMP", color="orange")
plt.semilogy(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
# -10dB for 15 layers/iterations
# lista used 5 epochs and a batch size of 128
# lista started to blow up so on the last few layers I only used between 1-3 epochs
lista = [0.021333517506718636, 0.01833442971110344, 0.018053462728857994, 0.018155626952648163, 0.018238697201013565, 0.018313223496079445, 0.018304990604519844, 0.018311165273189545, 0.01833927631378174, 0.01834440790116787, .0202, .0205, .0194, .0202, .0202]
amp = [0.042536572524738844,0.041630010941504245,0.041338066287964055,0.039319839423644476,0.04100932476211079,0.04364813887356411,0.04462309481726083,0.044012216504439566,0.04217716791718202,0.04322930095625426,0.04528661113052591,0.04416056414004061,0.0414091099464235,0.04118446068403413,0.0367644261739721]
ist = [0.03130110423017185,0.029713600695747973,0.02880401877312813,0.028079541658306267,0.027475660841896885,0.02695381576248628,0.02649659719684898,0.026089521346365607,0.025717406579082468,0.02537945627075352,0.025070335251730948,0.024785952424284684,0.024523349196199376,0.02427797230394986,0.02404879546942162]

plt.figure()
plt.title("MSE vs. iterations: SNR = -10dB")
plt.plot(range(1, 16), lista, label="LISTA", color="blue")
plt.plot(range(1, 16), amp, label="AMP", color="orange")
plt.plot(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations: SNR = -10dB")
plt.semilogy(range(1, 16), lista, label="LISTA", color="blue")
plt.semilogy(range(1, 16), amp, label="AMP", color="orange")
plt.semilogy(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
# -5dB for 15 layers/iterations
# lista used 5 epochs and a batch size of 128
# lista started to blow up so on the last few layers I only used between 1-3 epochs
lista = [0.017699789255857468, 0.01234059315174818, 0.010570346377789974, 0.009869382716715336, 0.009606722742319107, 0.009507767856121063, 0.009500621818006039, 0.00952985230833292, 0.009520245715975761, 0.009483673609793186, .0101, .0101, .0109, .0109, .0109]
amp =[0.04066420591904486,0.038499288406953755,0.03392902347931667,0.03157122282715988,0.03268840046408291,0.03011286518903275,0.02825276928842227,0.029157349029484532,0.028616126465772676,0.02664598832453543,0.02718932491908254,0.027829014857302478,0.02570964005168764,0.02524781874026014,0.02467053012438485]
ist = [0.03077993048054235,0.029215574902858782,0.02797614168762664,0.027137360806413196,0.026381554123358936,0.02572419495037036,0.025126600310185057,0.024580968328227648,0.02407798942470754,0.023610156261328223,0.023173397372111906,0.022763307967208546,0.02237658227656099,0.022011009386826104,0.021664178207796283]

plt.figure()
plt.title("MSE vs. iterations: SNR = -5dB")
plt.plot(range(1, 16), lista, label="LISTA", color="blue")
plt.plot(range(1, 16), amp, label="AMP", color="orange")
plt.plot(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations: SNR = -5dB")
plt.semilogy(range(1, 16), lista, label="LISTA", color="blue")
plt.semilogy(range(1, 16), amp, label="AMP", color="orange")
plt.semilogy(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
# 1dB for 15 layers/iterations
# lista used 5 epochs and a batch size of 128
lista = [0.016032986342906952, 0.009649376384913921, 0.007187374401837587, 0.005947991274297237, 0.0052980887703597546, 0.004880562424659729, 0.0046090297400951385, 0.004430170636624098, 0.004287408664822578, 0.004180466756224632, 0.0041537657380104065, 0.004078570753335953, 0.003991100005805492, 0.004010610282421112, 0.003989187069237232]
amp = [0.037649430442267116,0.03234290652723748,0.026692771119229672,0.01854601986792046,0.015418047401002518,0.01388256147805099,0.012412517632075336,0.010934630099492538,0.008880919009809182,0.007589467003234095,0.0071396941722272865,0.006839482484537232,0.0064463627172903475,0.005830602220876821,0.005487799345534465]
ist = [0.030665644950873587,0.028885095883831438,0.027355214129783617,0.02628919474789311,0.02530572837211425,0.024436904589197898,0.02363997213237954,0.022903455350931155,0.0222156616609299,0.0215694238423046,0.020959527324630044,0.02038162437065978,0.019832948846320125,0.01931049338973357,0.018811528923529282] 

plt.figure()
plt.title("MSE vs. iterations: SNR = 1dB")
plt.plot(range(1, 16), lista, label="LISTA", color="blue")
plt.plot(range(1, 16), amp, label="AMP", color="orange")
plt.plot(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations: SNR = 1dB")
plt.semilogy(range(1, 16), lista, label="LISTA", color="blue")
plt.semilogy(range(1, 16), amp, label="AMP", color="orange")
plt.semilogy(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
# 5dB for 15 layers/iterations
# lista used 5 epochs and a batch size of 128
lista = [0.015756797045469284, 0.009136275388300419, 0.006486981175839901, 0.005166704300791025, 0.004375395365059376, 0.003929701633751392, 0.003507036715745926, 0.0032327743247151375, 0.0029574488289654255, 0.0027793440967798233, 0.0026270633097738028, 0.00248361611738801, 0.0024041826836764812, 0.00227207294665277, 0.002205316908657551]
amp = [0.031038107858390278,0.024401092251217185,0.020635210733098364,0.016739729846070535,0.014255246657615957,0.011870473676761964,0.010260816213938484,0.00849152705171733,0.007281766669754975,0.006088401663505753,0.005833572385889376,0.0053025817048137375,0.004616837067123746,0.004017782314906303,0.0038383941492646807]
ist = [0.02987737741410481,0.027645978019984765,0.026036064043842767,0.02484736955724684,0.023814773402866835,0.02290539982392302,0.022082240690104164,0.021326506443042542,0.020624855899253308,0.019967893435563128,0.01934952617696232,0.018764411188283783,0.018208807013380797,0.017679943131117468,0.01717493333136831]

plt.figure()
plt.title("MSE vs. iterations: SNR = 5dB")
plt.plot(range(1, 16), lista, label="LISTA", color="blue")
plt.plot(range(1, 16), amp, label="AMP", color="orange")
plt.plot(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations: SNR = 5dB")
plt.semilogy(range(1, 16), lista, label="LISTA", color="blue")
plt.semilogy(range(1, 16), amp, label="AMP", color="orange")
plt.semilogy(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
# 10dB for 15 layers/iterations
# lista used 5 epochs and a batch size of 128
lista = [0.015658477321267128, 0.00889404397457838, 0.0061620911583304405, 0.004787910729646683, 0.00397701608017087, 0.003406099509447813, 0.0029604174196720123, 0.002575843594968319, 0.002302170032635331, 0.0020288543310016394, 0.0018335116328671575, 0.0016968444688245654, 0.0015057155396789312, 0.0014508154708892107, 0.0013345531187951565]
amp = [0.03248561880551619,0.027643287730485702,0.023214013840104346,0.0217425995583933,0.019359565503711797,0.016691177097701203,0.014572663528385807,0.013274367778077526,0.011762898426657975,0.011467537514080577,0.011624418389670679,0.010111572894575264,0.008715518434007183,0.007912752731465616,0.006776703445053934]
ist = [0.031051015278165037,0.029230904515032297,0.027899303906690938,0.026908421558186617,0.026046753910001705,0.02527179566371246,0.0245680814703605,0.023920352248133006,0.023319639582500547,0.02276049789516362,0.022235766297578112,0.021741786069688664,0.02127518895820201,0.020831175943718753,0.02040782263522968]

plt.figure()
plt.title("MSE vs. iterations: SNR = 10dB")
plt.plot(range(1, 16), lista, label="LISTA", color="blue")
plt.plot(range(1, 16), amp, label="AMP", color="orange")
plt.plot(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations: SNR = 10dB")
plt.semilogy(range(1, 16), lista, label="LISTA", color="blue")
plt.semilogy(range(1, 16), amp, label="AMP", color="orange")
plt.semilogy(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

# %%
# 20dB for 15 layers/iterations
# lista used 5 epochs and a batch size of 128
lista = [0.01549831684678793, 0.008718709461390972, 0.005984623916447163, 0.004608457442373037, 0.0037937716115266085, 0.0032242578454315662, 0.0027441333513706923, 0.0023581760469824076, 0.002047143178060651, 0.001754908007569611, 0.001568634994328022, 0.0013941447250545025, 0.0012565794168040156, 0.0011705009965226054, 0.0010929573327302933]
amp = [0.03226185537992994,0.024980605314370873,0.02163170565017844,0.018338400747066025,0.01781538491370422,0.014458325928987551,0.01189920425573871,0.010775112722994976,0.009292118182325398,0.008542847361299118,0.007325594220104241,0.005863524619728841,0.0049854526883804234,0.004295229899584973,0.0035066210567166398]
ist = [0.030068721950043203,0.028052711153760925,0.02647334785157826,0.02529950973110784,0.024258204216864927,0.023336917392344135,0.022497189985768565,0.02172265007581471,0.02099944461073984,0.020318421681656672,0.019672852635282498,0.019058940031281568,0.018472941181380084,0.01791276354094115,0.01737573201177796]

plt.figure()
plt.title("MSE vs. iterations: SNR = 20dB")
plt.plot(range(1, 16), lista, label="LISTA", color="blue")
plt.plot(range(1, 16), amp, label="AMP", color="orange")
plt.plot(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()

plt.title("MSE vs. iterations: SNR = 20dB")
plt.semilogy(range(1, 16), lista, label="LISTA", color="blue")
plt.semilogy(range(1, 16), amp, label="AMP", color="orange")
plt.semilogy(range(1,16), ist, label="IST", color="green")
plt.grid(True, which='both')
plt.legend()
plt.xlabel('Iteration Number')
plt.ylabel('MSE')
plt.show()
